# %%
# Bibliotecas

import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Carregar a planilha e depois selecionar as colunas de interesse
df = pd.read_excel(r"C:\Users\hugob\Downloads\Relatório Geral de Estudantes - Matrículas - 17.10.xlsx")
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#        Relatório Geral de Estudantes - Matrículas Unnamed: 1    Unnamed: 2  \
# 0                      Gerado em 17/10/2025 09:45        NaN           NaN
# 1                                             ANO    PERÍODO     MATRÍCULA
# 2                                            2025          1  202230683131
# 3                                            2025          1  202430157363
# 4                                            2025          1  202430266223
# ...                                           ...        ...           ...
# 184773                                       2025          1  202530499442
# 184774                                       2025          1  202530499451
# 184775                                       2025          1  202530499460
# 184776                                       2025          1  202430001344
# 184777                                       2025          1  202530499470
#
#                              Unnamed: 3  \
# 0                                   NaN
# 1       DATA DE EFETIVAÇÃO DA MATRÍCULA
# 2                            13/11/2024
# 3                            13/11/2024
# 4                            14/11/2024
# ...                                 ...
# 184773                       17/10/2025
# 184774                       17/10/2025
# 184775                       17/10/2025
# 184776                       17/10/2025
# 184777                       17/10/2025
#
#                                     Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0                                          NaN          NaN        NaN
# 1                                         NOME  NOME SOCIAL  ID_PESSOA
# 2                         BRUNO CORTES SANTANA            -    1382152
# 3            JALLYSON MIGUEL SILVA DE OLIVEIRA            -    1478210
# 4                    ANA SOPHIA ABREU DA SILVA            -    1489101
# ...                                        ...          ...        ...
# 184773  MIQUEIAS PYETRO DO NASCIMENTO FERREIRA            -    1583774
# 184774            NICOLAS GABRIEL MAIA DE LIMA            -    1583775
# 184775              JOAO MIGUEL FELIX DA SILVA            -    1583784
# 184776          RAYRA VITORIA ANSELMO DE SOUZA            -    1458734
# 184777               JOAO PAULO FELIX DA SILVA            -    1583785
#
#        Unnamed: 7                             Unnamed: 8  \
# 0             NaN                                    NaN
# 1            SEXO                     NOME DA FILIAÇÃO 1
# 2               M           LUCIANA COSTA CORTES SANTANA
# 3               M                   MARIANA SILVA FARIAS
# 4               F        SUELEN CRISTINA DE ABREU LORENA
# ...           ...                                    ...
# 184773          M  FRANCISCA EDILENE DO NASCIMENTO BRITO
# 184774          M   PATRICIA NATHIELY GOMES DE LIMA MAIA
# 184775          M                   RAIZA FELIX DA COSTA
# 184776          F              ROSILENE ANSELMO DE SOUZA
# 184777          M                   RAIZA FELIX DA COSTA
#
#                              Unnamed: 9  ...       Unnamed: 33  Unnamed: 34  \
# 0                                   NaN  ...               NaN          NaN
# 1                    NOME DA FILIAÇÃO 2  ...  DATA DA OPERAÇÃO  RESPÓNSÁVEL
# 2                                   NaN  ...        2025-03-10            -
# 3           JANAILSON LOPES DE OLIVEIRA  ...        2025-03-10            -
# 4            JOSE PAULO DA SILVA JUNIOR  ...        2025-03-10            -
# ...                                 ...  ...               ...          ...
# 184773  MIQUEIAS FERREIRA DO NASCIMENTO  ...        2025-10-17            -
# 184774     DUYLIO MAXMILIANO MAIA LEITE  ...        2025-10-17            -
# 184775              JOAO MARIA DA SILVA  ...        2025-10-17            -
# 184776       JOSENILDO MEENDES DE SOUSA  ...        2025-10-17            -
# 184777              JOAO MARIA DA SILVA  ...        2025-10-17            -
#
#                Unnamed: 35   Unnamed: 36 Unnamed: 37           Unnamed: 38  \
# 0                      NaN           NaN         NaN                   NaN
# 1       MATRICULA SERVIDOR         LOGIN  ID_USUÁRIO  PARTICIPA PÉ DE MEIA
# 2                        -             -           -                   Não
# 3                        -             -           -                   Não
# 4                        -             -           -                   Não
# ...                    ...           ...         ...                   ...
# 184773                   -             -           -                   Não
# 184774                   -             -           -                   Não
# 184775                   -             -           -                   Não
# 184776                   -  202530007171    61984617                   Não
# 184777                   -             -           -                   Não
#
#        Unnamed: 39                 Unnamed: 40                 Unnamed: 41  \
# 0              NaN                         NaN                         NaN
# 1       RAÇA / COR  UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR
# 2            Parda                         Não                           -
# 3            Parda                         Sim                Micro-ônibus
# 4            Parda                         Não                           -
# ...            ...                         ...                         ...
# 184773       Preta                         Não                           -
# 184774      Branca                         Não                           -
# 184775      Branca                         Não                           -
# 184776       Parda                         Não                           -
# 184777       Parda                         Não                           -
#
#        Unnamed: 42
# 0              NaN
# 1             TIPO
# 2                -
# 3         ESTADUAL
# 4                -
# ...            ...
# 184773           -
# 184774           -
# 184775           -
# 184776           -
# 184777           -
#
# [184778 rows x 43 columns]

# %%
df = df.drop(index=0)

# %%
df.columns = df.iloc[0]

# %%
df
# Out:
# 1        ANO  PERÍODO     MATRÍCULA  DATA DE EFETIVAÇÃO DA MATRÍCULA  \
# 1        ANO  PERÍODO     MATRÍCULA  DATA DE EFETIVAÇÃO DA MATRÍCULA
# 2       2025        1  202230683131                       13/11/2024
# 3       2025        1  202430157363                       13/11/2024
# 4       2025        1  202430266223                       14/11/2024
# 5       2025        1  202330270018                       14/11/2024
# ...      ...      ...           ...                              ...
# 184773  2025        1  202530499442                       17/10/2025
# 184774  2025        1  202530499451                       17/10/2025
# 184775  2025        1  202530499460                       17/10/2025
# 184776  2025        1  202430001344                       17/10/2025
# 184777  2025        1  202530499470                       17/10/2025
#
# 1                                         NOME  NOME SOCIAL  ID_PESSOA  SEXO  \
# 1                                         NOME  NOME SOCIAL  ID_PESSOA  SEXO
# 2                         BRUNO CORTES SANTANA            -    1382152     M
# 3            JALLYSON MIGUEL SILVA DE OLIVEIRA            -    1478210     M
# 4                    ANA SOPHIA ABREU DA SILVA            -    1489101     F
# 5               ARTHUR WILLIAM DA SILVA FARIAS            -    1412594     M
# ...                                        ...          ...        ...   ...
# 184773  MIQUEIAS PYETRO DO NASCIMENTO FERREIRA            -    1583774     M
# 184774            NICOLAS GABRIEL MAIA DE LIMA            -    1583775     M
# 184775              JOAO MIGUEL FELIX DA SILVA            -    1583784     M
# 184776          RAYRA VITORIA ANSELMO DE SOUZA            -    1458734     F
# 184777               JOAO PAULO FELIX DA SILVA            -    1583785     M
#
# 1                          NOME DA FILIAÇÃO 1  \
# 1                          NOME DA FILIAÇÃO 1
# 2                LUCIANA COSTA CORTES SANTANA
# 3                        MARIANA SILVA FARIAS
# 4             SUELEN CRISTINA DE ABREU LORENA
# 5                       JAIANE SILVA DE SOUZA
# ...                                       ...
# 184773  FRANCISCA EDILENE DO NASCIMENTO BRITO
# 184774   PATRICIA NATHIELY GOMES DE LIMA MAIA
# 184775                   RAIZA FELIX DA COSTA
# 184776              ROSILENE ANSELMO DE SOUZA
# 184777                   RAIZA FELIX DA COSTA
#
# 1                    NOME DA FILIAÇÃO 2  ...  DATA DA OPERAÇÃO  RESPÓNSÁVEL  \
# 1                    NOME DA FILIAÇÃO 2  ...  DATA DA OPERAÇÃO  RESPÓNSÁVEL
# 2                                   NaN  ...        2025-03-10            -
# 3           JANAILSON LOPES DE OLIVEIRA  ...        2025-03-10            -
# 4            JOSE PAULO DA SILVA JUNIOR  ...        2025-03-10            -
# 5                HERING NOBRE DE FARIAS  ...        2025-03-10            -
# ...                                 ...  ...               ...          ...
# 184773  MIQUEIAS FERREIRA DO NASCIMENTO  ...        2025-10-17            -
# 184774     DUYLIO MAXMILIANO MAIA LEITE  ...        2025-10-17            -
# 184775              JOAO MARIA DA SILVA  ...        2025-10-17            -
# 184776       JOSENILDO MEENDES DE SOUSA  ...        2025-10-17            -
# 184777              JOAO MARIA DA SILVA  ...        2025-10-17            -
#
# 1       MATRICULA SERVIDOR         LOGIN  ID_USUÁRIO  PARTICIPA PÉ DE MEIA  \
# 1       MATRICULA SERVIDOR         LOGIN  ID_USUÁRIO  PARTICIPA PÉ DE MEIA
# 2                        -             -           -                   Não
# 3                        -             -           -                   Não
# 4                        -             -           -                   Não
# 5                        -  202330270018    61904897                   Não
# ...                    ...           ...         ...                   ...
# 184773                   -             -           -                   Não
# 184774                   -             -           -                   Não
# 184775                   -             -           -                   Não
# 184776                   -  202530007171    61984617                   Não
# 184777                   -             -           -                   Não
#
# 1       RAÇA / COR  UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR  \
# 1       RAÇA / COR  UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR
# 2            Parda                         Não                           -
# 3            Parda                         Sim                Micro-ônibus
# 4            Parda                         Não                           -
# 5            Parda                         Não                           -
# ...            ...                         ...                         ...
# 184773       Preta                         Não                           -
# 184774      Branca                         Não                           -
# 184775      Branca                         Não                           -
# 184776       Parda                         Não                           -
# 184777       Parda                         Não                           -
#
# 1           TIPO
# 1           TIPO
# 2              -
# 3       ESTADUAL
# 4              -
# 5              -
# ...          ...
# 184773         -
# 184774         -
# 184775         -
# 184776         -
# 184777         -
#
# [184777 rows x 43 columns]

# %%
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 1        ANO PERÍODO     MATRÍCULA DATA DE EFETIVAÇÃO DA MATRÍCULA  \
# 0       2025       1  202230683131                      13/11/2024
# 1       2025       1  202430157363                      13/11/2024
# 2       2025       1  202430266223                      14/11/2024
# 3       2025       1  202330270018                      14/11/2024
# 4       2025       1  202130048235                      14/11/2024
# ...      ...     ...           ...                             ...
# 184771  2025       1  202530499442                      17/10/2025
# 184772  2025       1  202530499451                      17/10/2025
# 184773  2025       1  202530499460                      17/10/2025
# 184774  2025       1  202430001344                      17/10/2025
# 184775  2025       1  202530499470                      17/10/2025
#
# 1                                         NOME NOME SOCIAL ID_PESSOA SEXO  \
# 0                         BRUNO CORTES SANTANA           -   1382152    M
# 1            JALLYSON MIGUEL SILVA DE OLIVEIRA           -   1478210    M
# 2                    ANA SOPHIA ABREU DA SILVA           -   1489101    F
# 3               ARTHUR WILLIAM DA SILVA FARIAS           -   1412594    M
# 4                       DAVI LUCAS SOUZA SILVA           -   1217368    M
# ...                                        ...         ...       ...  ...
# 184771  MIQUEIAS PYETRO DO NASCIMENTO FERREIRA           -   1583774    M
# 184772            NICOLAS GABRIEL MAIA DE LIMA           -   1583775    M
# 184773              JOAO MIGUEL FELIX DA SILVA           -   1583784    M
# 184774          RAYRA VITORIA ANSELMO DE SOUZA           -   1458734    F
# 184775               JOAO PAULO FELIX DA SILVA           -   1583785    M
#
# 1                          NOME DA FILIAÇÃO 1  \
# 0                LUCIANA COSTA CORTES SANTANA
# 1                        MARIANA SILVA FARIAS
# 2             SUELEN CRISTINA DE ABREU LORENA
# 3                       JAIANE SILVA DE SOUZA
# 4                PATRICIA SILVA LIMA DE SOUZA
# ...                                       ...
# 184771  FRANCISCA EDILENE DO NASCIMENTO BRITO
# 184772   PATRICIA NATHIELY GOMES DE LIMA MAIA
# 184773                   RAIZA FELIX DA COSTA
# 184774              ROSILENE ANSELMO DE SOUZA
# 184775                   RAIZA FELIX DA COSTA
#
# 1                    NOME DA FILIAÇÃO 2  ... DATA DA OPERAÇÃO RESPÓNSÁVEL  \
# 0                                   NaN  ...       2025-03-10           -
# 1           JANAILSON LOPES DE OLIVEIRA  ...       2025-03-10           -
# 2            JOSE PAULO DA SILVA JUNIOR  ...       2025-03-10           -
# 3                HERING NOBRE DE FARIAS  ...       2025-03-10           -
# 4                DANIEL SOUZA MARCOLINO  ...       2025-03-13           -
# ...                                 ...  ...              ...         ...
# 184771  MIQUEIAS FERREIRA DO NASCIMENTO  ...       2025-10-17           -
# 184772     DUYLIO MAXMILIANO MAIA LEITE  ...       2025-10-17           -
# 184773              JOAO MARIA DA SILVA  ...       2025-10-17           -
# 184774       JOSENILDO MEENDES DE SOUSA  ...       2025-10-17           -
# 184775              JOAO MARIA DA SILVA  ...       2025-10-17           -
#
# 1      MATRICULA SERVIDOR         LOGIN ID_USUÁRIO PARTICIPA PÉ DE MEIA  \
# 0                       -             -          -                  Não
# 1                       -             -          -                  Não
# 2                       -             -          -                  Não
# 3                       -  202330270018   61904897                  Não
# 4                       -             -          -                  Não
# ...                   ...           ...        ...                  ...
# 184771                  -             -          -                  Não
# 184772                  -             -          -                  Não
# 184773                  -             -          -                  Não
# 184774                  -  202530007171   61984617                  Não
# 184775                  -             -          -                  Não
#
# 1      RAÇA / COR UTILIZA TRANSPORTE ESCOLAR TIPO DE TRANSPORTE ESCOLAR  \
# 0           Parda                        Não                          -
# 1           Parda                        Sim               Micro-ônibus
# 2           Parda                        Não                          -
# 3           Parda                        Não                          -
# 4           Parda                        Não                          -
# ...           ...                        ...                        ...
# 184771      Preta                        Não                          -
# 184772     Branca                        Não                          -
# 184773     Branca                        Não                          -
# 184774      Parda                        Não                          -
# 184775      Parda                        Não                          -
#
# 1           TIPO
# 0              -
# 1       ESTADUAL
# 2              -
# 3              -
# 4              -
# ...          ...
# 184771         -
# 184772         -
# 184773         -
# 184774         -
# 184775         -
#
# [184776 rows x 43 columns]

# %%
# Deixar somente as 2 colunas de interesse (CPF e DATA DE NASCIMENTO)
df = df[['CPF', 'DATA DE NASCIMENTO']]

# %%
df
# Out:
# 1                  CPF   DATA DE NASCIMENTO
# 0       073.022.765-01  2012-10-31 00:00:00
# 1       141.327.644-00  2016-03-02 00:00:00
# 2       147.265.004-22  2017-08-17 00:00:00
# 3       712.292.714-81  2015-09-30 00:00:00
# 4       131.642.894-05  2015-02-23 00:00:00
# ...                ...                  ...
# 184771  632.167.823-60  2008-06-18 00:00:00
# 184772  156.766.714-75  2018-07-02 00:00:00
# 184773  145.185.314-93  2016-12-20 00:00:00
# 184774  700.696.554-30  2011-04-25 00:00:00
# 184775  177.601.754-42  2015-03-21 00:00:00
#
# [184776 rows x 2 columns]

# %%
# Definir a data de referência para calcular a idade (01 de março de 2025)
data_referencia = datetime(2025, 3, 1)

# %%
# Converter a coluna de data para formato datetime
df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%d/%m/%Y %H:%M')
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_11380\199283761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%d/%m/%Y %H:%M')

# %%
# Calcular as idades usando a data de referência
df['IDADE'] = (data_referencia - df['DATA DE NASCIMENTO']).dt.days // 365
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_11380\1383963767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IDADE'] = (data_referencia - df['DATA DE NASCIMENTO']).dt.days // 365

# %%
df
# Out:
# 1                  CPF DATA DE NASCIMENTO  IDADE
# 0       073.022.765-01         2012-10-31     12
# 1       141.327.644-00         2016-03-02      9
# 2       147.265.004-22         2017-08-17      7
# 3       712.292.714-81         2015-09-30      9
# 4       131.642.894-05         2015-02-23     10
# ...                ...                ...    ...
# 184771  632.167.823-60         2008-06-18     16
# 184772  156.766.714-75         2018-07-02      6
# 184773  145.185.314-93         2016-12-20      8
# 184774  700.696.554-30         2011-04-25     13
# 184775  177.601.754-42         2015-03-21      9
#
# [184776 rows x 3 columns]

# %%
# Carregar a planilha e depois selecionar as colunas de interesse
df_notas = pd.read_parquet(r"C:\Users\hugob\Downloads\df_EF_EM_bncc_censo.parquet")

# %%
df_notas
# Out:
#                              DIREC                MUNICÍPIO  \
# 1976             10ª DIREC - CAICÓ                    CAICO
# 1977             10ª DIREC - CAICÓ                    CAICO
# 1978             10ª DIREC - CAICÓ                    CAICO
# 1979             10ª DIREC - CAICÓ                    CAICO
# 1980             10ª DIREC - CAICÓ                    CAICO
# ...                            ...                      ...
# 2963127  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2963128  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2963129  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2963134  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2963140  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
#
#                                                     ESCOLA  INEP ESCOLA  \
# 1976                                       CE JOSE AUGUSTO     24031348
# 1977                                       CE JOSE AUGUSTO     24031348
# 1978                                       CE JOSE AUGUSTO     24031348
# 1979                                       CE JOSE AUGUSTO     24031348
# 1980                                       CE JOSE AUGUSTO     24031348
# ...                                                    ...          ...
# 2963127  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2963128  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2963129  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2963134  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2963140  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
#
#                                               ETAPA ENSINO     SÉRIE  \
# 1976     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1977     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1978     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1979     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1980     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# ...                                                    ...       ...
# 2963127            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2963128            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2963129            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2963134            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2963140            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
#
#         COMPONENTE CURRICULAR   CPF PESSOA                      NOME PESSOA  \
# 1976                     Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1977                     Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1978                 Biologia  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1979          Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1980          Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# ...                       ...          ...                              ...
# 2963127     Língua Portuguesa  13717816489          WELLINGTON ARAUJO FELIX
# 2963128            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 2963129            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 2963134               Química  13717816489          WELLINGTON ARAUJO FELIX
# 2963140            Sociologia  13717816489          WELLINGTON ARAUJO FELIX
#
#          NOTA 1º BIMESTRE  NOTA 2º BIMESTRE  NOTA 3º BIMESTRE  \
# 1976                  8.6               9.0               NaN
# 1977                  8.6               9.0               NaN
# 1978                  6.8               7.1               NaN
# 1979                  8.3               9.0               NaN
# 1980                  8.3               9.0               NaN
# ...                   ...               ...               ...
# 2963127               4.6               4.2               NaN
# 2963128               6.1               3.3               NaN
# 2963129               6.1               3.3               NaN
# 2963134               6.0               6.0               6.0
# 2963140               8.0               8.0               8.5
#
#          NOTA 4º BIMESTRE  MÉDIA ANUAL  EXAME FINAL  AVALIAÇÃO ESPECIAL  \
# 1976                  NaN          NaN          NaN                 NaN
# 1977                  NaN          NaN          NaN                 NaN
# 1978                  NaN          NaN          NaN                 NaN
# 1979                  NaN          NaN          NaN                 NaN
# 1980                  NaN          NaN          NaN                 NaN
# ...                   ...          ...          ...                 ...
# 2963127               NaN          NaN          NaN                 NaN
# 2963128               NaN          NaN          NaN                 NaN
# 2963129               NaN          NaN          NaN                 NaN
# 2963134               NaN          NaN          NaN                 NaN
# 2963140               NaN          NaN          NaN                 NaN
#
#          MÉDIA FINAL ETAPA_RESUMIDA  MEDIA_1_2_BIM     STATUS
# 1976             NaN   Ensino Médio           8.80   Aprovado
# 1977             NaN   Ensino Médio           8.80   Aprovado
# 1978             NaN   Ensino Médio           6.95   Aprovado
# 1979             NaN   Ensino Médio           8.65   Aprovado
# 1980             NaN   Ensino Médio           8.65   Aprovado
# ...              ...            ...            ...        ...
# 2963127          NaN   Ensino Médio           4.40  Reprovado
# 2963128          NaN   Ensino Médio           4.70  Reprovado
# 2963129          NaN   Ensino Médio           4.70  Reprovado
# 2963134          NaN   Ensino Médio           6.00   Aprovado
# 2963140          NaN   Ensino Médio           8.00   Aprovado
#
# [1525811 rows x 20 columns]

# %%
df['CPF'] = df['CPF'].astype(str).str.replace('.', '', regex=False).str.replace('-', '', regex=False)
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_11380\1005790323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CPF'] = df['CPF'].astype(str).str.replace('.', '', regex=False).str.replace('-', '', regex=False)

# %%
# MErge para adicionar idade no dataframe df_notas

df_notas = df_notas.merge(
    df[['CPF', 'IDADE']],      # DataFrame com as colunas que você quer trazer
    how='left',                # mantém todas as linhas do df_notas
    left_on='CPF PESSOA',      # coluna de df_notas usada para combinar
    right_on='CPF'             # coluna de df usada para combinar
)

# %%
df_notas
# Out:
#                              DIREC                MUNICÍPIO  \
# 0                10ª DIREC - CAICÓ                    CAICO
# 1                10ª DIREC - CAICÓ                    CAICO
# 2                10ª DIREC - CAICÓ                    CAICO
# 3                10ª DIREC - CAICÓ                    CAICO
# 4                10ª DIREC - CAICÓ                    CAICO
# ...                            ...                      ...
# 1530730  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1530731  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1530732  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1530733  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1530734  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
#
#                                                     ESCOLA  INEP ESCOLA  \
# 0                                          CE JOSE AUGUSTO     24031348
# 1                                          CE JOSE AUGUSTO     24031348
# 2                                          CE JOSE AUGUSTO     24031348
# 3                                          CE JOSE AUGUSTO     24031348
# 4                                          CE JOSE AUGUSTO     24031348
# ...                                                    ...          ...
# 1530730  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1530731  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1530732  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1530733  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1530734  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
#
#                                               ETAPA ENSINO     SÉRIE  \
# 0        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 3        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 4        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# ...                                                    ...       ...
# 1530730            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1530731            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1530732            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1530733            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1530734            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
#
#         COMPONENTE CURRICULAR   CPF PESSOA                      NOME PESSOA  \
# 0                        Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1                        Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2                    Biologia  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 3             Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 4             Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# ...                       ...          ...                              ...
# 1530730     Língua Portuguesa  13717816489          WELLINGTON ARAUJO FELIX
# 1530731            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 1530732            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 1530733               Química  13717816489          WELLINGTON ARAUJO FELIX
# 1530734            Sociologia  13717816489          WELLINGTON ARAUJO FELIX
#
#          NOTA 1º BIMESTRE  ...  NOTA 4º BIMESTRE  MÉDIA ANUAL  EXAME FINAL  \
# 0                     8.6  ...               NaN          NaN          NaN
# 1                     8.6  ...               NaN          NaN          NaN
# 2                     6.8  ...               NaN          NaN          NaN
# 3                     8.3  ...               NaN          NaN          NaN
# 4                     8.3  ...               NaN          NaN          NaN
# ...                   ...  ...               ...          ...          ...
# 1530730               4.6  ...               NaN          NaN          NaN
# 1530731               6.1  ...               NaN          NaN          NaN
# 1530732               6.1  ...               NaN          NaN          NaN
# 1530733               6.0  ...               NaN          NaN          NaN
# 1530734               8.0  ...               NaN          NaN          NaN
#
#          AVALIAÇÃO ESPECIAL  MÉDIA FINAL  ETAPA_RESUMIDA  MEDIA_1_2_BIM  \
# 0                       NaN          NaN    Ensino Médio           8.80
# 1                       NaN          NaN    Ensino Médio           8.80
# 2                       NaN          NaN    Ensino Médio           6.95
# 3                       NaN          NaN    Ensino Médio           8.65
# 4                       NaN          NaN    Ensino Médio           8.65
# ...                     ...          ...             ...            ...
# 1530730                 NaN          NaN    Ensino Médio           4.40
# 1530731                 NaN          NaN    Ensino Médio           4.70
# 1530732                 NaN          NaN    Ensino Médio           4.70
# 1530733                 NaN          NaN    Ensino Médio           6.00
# 1530734                 NaN          NaN    Ensino Médio           8.00
#
#             STATUS          CPF IDADE
# 0         Aprovado  70602180414  15.0
# 1         Aprovado  70602180414  15.0
# 2         Aprovado  70602180414  15.0
# 3         Aprovado  70602180414  15.0
# 4         Aprovado  70602180414  15.0
# ...            ...          ...   ...
# 1530730  Reprovado  13717816489  18.0
# 1530731  Reprovado  13717816489  18.0
# 1530732  Reprovado  13717816489  18.0
# 1530733   Aprovado  13717816489  18.0
# 1530734   Aprovado  13717816489  18.0
#
# [1530735 rows x 22 columns]

# %%
# Função auxiliar para pegar o valor mais frequente (modo)
def modo(serie):
    return serie.mode()[0] if not serie.mode().empty else None

# Agrupar e calcular
df_reprovacoes = (
    df_notas.groupby('CPF PESSOA', as_index=False)
    .agg({
        'STATUS': lambda x: (x == 'Reprovado').sum(),  # Conta quantos "Reprovado"
        'IDADE': modo,                                # Valor mais frequente da idade
        'SÉRIE': modo                                 # Valor mais frequente da série
    })
)

# Renomear a coluna resultante
df_reprovacoes.rename(columns={'STATUS': 'TOTAL_REPROVACOES'}, inplace=True)

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE
# 0       10000150410                  6   17.0  3ª SÉRIE
# 1       10000254460                  0   16.0  1ª SÉRIE
# 2       10000823422                  0   17.0  3ª SÉRIE
# 3       10000982490                  1   16.0  2ª SÉRIE
# 4       10001165496                  2   16.0  2ª SÉRIE
# ...             ...                ...    ...       ...
# 132235   9997488407                  1    NaN  2ª SÉRIE
# 132236   9998899400                  0    NaN  2ª SÉRIE
# 132237   9999048412                  0    NaN  3ª SÉRIE
# 132238    999906445                  0    NaN  3ª SÉRIE
# 132239   9999339492                  0    NaN  2ª SÉRIE
#
# [132240 rows x 4 columns]

# %%
df_reprovacoes['SÉRIE'].unique()
# Out:
# array(['3ª SÉRIE', '1ª SÉRIE', '2ª SÉRIE', '9º ANO', '6º ANO', '8º ANO',
#        '7º ANO'], dtype=object)

# %%
# Dicionário de mapeamento entre série e idade esperada
mapa_idade_esperada = {
    '6º ANO': 11,
    '7º ANO': 12,
    '8º ANO': 13,
    '9º ANO': 14,
    '1ª SÉRIE': 15,
    '2ª SÉRIE': 16,
    '3ª SÉRIE': 17
}

# Criar nova coluna com base na série
df_reprovacoes['IDADE_ESPERADA'] = df_reprovacoes['SÉRIE'].map(mapa_idade_esperada)

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA
# 0       10000150410                  6   17.0  3ª SÉRIE              17
# 1       10000254460                  0   16.0  1ª SÉRIE              15
# 2       10000823422                  0   17.0  3ª SÉRIE              17
# 3       10000982490                  1   16.0  2ª SÉRIE              16
# 4       10001165496                  2   16.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 132235   9997488407                  1    NaN  2ª SÉRIE              16
# 132236   9998899400                  0    NaN  2ª SÉRIE              16
# 132237   9999048412                  0    NaN  3ª SÉRIE              17
# 132238    999906445                  0    NaN  3ª SÉRIE              17
# 132239   9999339492                  0    NaN  2ª SÉRIE              16
#
# [132240 rows x 5 columns]

# %%
# Diferença entre Idade e Idade Esperada
df_reprovacoes['DIFERENCA'] = df_reprovacoes['IDADE'] - df_reprovacoes['IDADE_ESPERADA']

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 0       10000150410                  6   17.0  3ª SÉRIE              17
# 1       10000254460                  0   16.0  1ª SÉRIE              15
# 2       10000823422                  0   17.0  3ª SÉRIE              17
# 3       10000982490                  1   16.0  2ª SÉRIE              16
# 4       10001165496                  2   16.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 132235   9997488407                  1    NaN  2ª SÉRIE              16
# 132236   9998899400                  0    NaN  2ª SÉRIE              16
# 132237   9999048412                  0    NaN  3ª SÉRIE              17
# 132238    999906445                  0    NaN  3ª SÉRIE              17
# 132239   9999339492                  0    NaN  2ª SÉRIE              16
#
#         DIFERENCA
# 0             0.0
# 1             1.0
# 2             0.0
# 3             0.0
# 4             0.0
# ...           ...
# 132235        NaN
# 132236        NaN
# 132237        NaN
# 132238        NaN
# 132239        NaN
#
# [132240 rows x 6 columns]

# %%
# Coluna de identificação dos estudantes em distorção idade-série (2 ou mais anos de diferença entre idade atual e idade esperada para a série)
df_reprovacoes['DISTORCAO'] = np.where(df_reprovacoes['DIFERENCA'] >= 2, 'Sim', 'Não')

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 0       10000150410                  6   17.0  3ª SÉRIE              17
# 1       10000254460                  0   16.0  1ª SÉRIE              15
# 2       10000823422                  0   17.0  3ª SÉRIE              17
# 3       10000982490                  1   16.0  2ª SÉRIE              16
# 4       10001165496                  2   16.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 132235   9997488407                  1    NaN  2ª SÉRIE              16
# 132236   9998899400                  0    NaN  2ª SÉRIE              16
# 132237   9999048412                  0    NaN  3ª SÉRIE              17
# 132238    999906445                  0    NaN  3ª SÉRIE              17
# 132239   9999339492                  0    NaN  2ª SÉRIE              16
#
#         DIFERENCA DISTORCAO
# 0             0.0       Não
# 1             1.0       Não
# 2             0.0       Não
# 3             0.0       Não
# 4             0.0       Não
# ...           ...       ...
# 132235        NaN       Não
# 132236        NaN       Não
# 132237        NaN       Não
# 132238        NaN       Não
# 132239        NaN       Não
#
# [132240 rows x 7 columns]

# %%
# Dataframe só com os estudantes com distção idade-série: 2 ou mais anos de diferença entre idade atual e idade esperada para a série)
df_distorcao = df_reprovacoes[df_reprovacoes['DISTORCAO'] == 'Sim'].copy()

# %%
df_distorcao
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 5       10001342452                  0   16.0    9º ANO              14
# 11      10005741483                  2   19.0  2ª SÉRIE              16
# 13      10005942462                  0   16.0    9º ANO              14
# 27      10010545476                 11   18.0  1ª SÉRIE              15
# 29      10012595489                  0   19.0  3ª SÉRIE              17
# ...             ...                ...    ...       ...             ...
# 131249  94196435491                  1   46.0  1ª SÉRIE              15
# 131274  94311943253                  0   20.0  1ª SÉRIE              15
# 131276  94336830487                  1   46.0  1ª SÉRIE              15
# 131604  96612770449                  0   57.0  3ª SÉRIE              17
# 131667  97025640425                  2   49.0  1ª SÉRIE              15
#
#         DIFERENCA DISTORCAO
# 5             2.0       Sim
# 11            3.0       Sim
# 13            2.0       Sim
# 27            3.0       Sim
# 29            2.0       Sim
# ...           ...       ...
# 131249       31.0       Sim
# 131274        5.0       Sim
# 131276       31.0       Sim
# 131604       40.0       Sim
# 131667       34.0       Sim
#
# [20749 rows x 7 columns]

# %%
# COluna de Etapa
# Definir as condições
condicoes = [
    df_distorcao['SÉRIE'].isin(['6º ANO', '7º ANO', '8º ANO', '9º ANO']),
    df_distorcao['SÉRIE'].isin(['1ª SÉRIE', '2ª SÉRIE', '3ª SÉRIE'])
]

# Definir os valores correspondentes
valores = [
    'Ensino Fundamental - Anos Finais',
    'Ensino Médio'
]

# Criar a nova coluna 'ETAPA'
df_distorcao['ETAPA'] = np.select(condicoes, valores, default='Outro')

# %%
df_distorcao
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 5       10001342452                  0   16.0    9º ANO              14
# 11      10005741483                  2   19.0  2ª SÉRIE              16
# 13      10005942462                  0   16.0    9º ANO              14
# 27      10010545476                 11   18.0  1ª SÉRIE              15
# 29      10012595489                  0   19.0  3ª SÉRIE              17
# ...             ...                ...    ...       ...             ...
# 131249  94196435491                  1   46.0  1ª SÉRIE              15
# 131274  94311943253                  0   20.0  1ª SÉRIE              15
# 131276  94336830487                  1   46.0  1ª SÉRIE              15
# 131604  96612770449                  0   57.0  3ª SÉRIE              17
# 131667  97025640425                  2   49.0  1ª SÉRIE              15
#
#         DIFERENCA DISTORCAO                             ETAPA
# 5             2.0       Sim  Ensino Fundamental - Anos Finais
# 11            3.0       Sim                      Ensino Médio
# 13            2.0       Sim  Ensino Fundamental - Anos Finais
# 27            3.0       Sim                      Ensino Médio
# 29            2.0       Sim                      Ensino Médio
# ...           ...       ...                               ...
# 131249       31.0       Sim                      Ensino Médio
# 131274        5.0       Sim                      Ensino Médio
# 131276       31.0       Sim                      Ensino Médio
# 131604       40.0       Sim                      Ensino Médio
# 131667       34.0       Sim                      Ensino Médio
#
# [20749 rows x 8 columns]

# %%
# Garantir que TOTAL_REPROVACOES é numérico
df_distorcao['TOTAL_REPROVACOES'] = pd.to_numeric(df_distorcao['TOTAL_REPROVACOES'], errors='coerce')

# Calcular as quantidades em cada faixa
qtd_7_ou_mais = (df_distorcao['TOTAL_REPROVACOES'] >= 7).sum()
qtd_4_a_6 = df_distorcao['TOTAL_REPROVACOES'].between(4, 6).sum()
qtd_3_ou_menos = (df_distorcao['TOTAL_REPROVACOES'] <= 3).sum()

# Mostrar o resultado
print("Total em distorção idade-série:", len(df_distorcao))
print("7 ou mais reprovações:", qtd_7_ou_mais)
print("4, 5 ou 6 reprovações:", qtd_4_a_6)
print("3 ou menos reprovações:", qtd_3_ou_menos)
# Out:
# Total em distorção idade-série: 20749
# 7 ou mais reprovações: 5602
# 4, 5 ou 6 reprovações: 5944
# 3 ou menos reprovações: 9203

# %%
# Cálculo por etapa:
# Agrupar por ETAPA e calcular as quantidades em cada faixa
resultado_por_etapa = (
    df_distorcao
    .groupby('ETAPA')
    .apply(lambda g: pd.Series({
        'Total em distorção idade-série': len(g),
        '7 ou mais reprovações': (g['TOTAL_REPROVACOES'] >= 7).sum(),
        '4, 5 ou 6 reprovações': g['TOTAL_REPROVACOES'].between(4, 6).sum(),
        '3 ou menos reprovações': (g['TOTAL_REPROVACOES'] <= 3).sum()
    }))
    .reset_index()
)

# %%
resultado_por_etapa
# Out:
#                               ETAPA  Total em distorção idade-série  \
# 0  Ensino Fundamental - Anos Finais                            5906
# 1                      Ensino Médio                           14843
#
#    7 ou mais reprovações  4, 5 ou 6 reprovações  3 ou menos reprovações
# 0                   1037                   2157                    2712
# 1                   4565                   3787                    6491

# %%
# Cálculo por SÉRIE:
# Agrupar por SÉRIE e calcular as quantidades em cada faixa
resultado_por_serie = (
    df_distorcao
    .groupby('SÉRIE')
    .apply(lambda g: pd.Series({
        'Total em distorção idade-série': len(g),
        '7 ou mais reprovações': (g['TOTAL_REPROVACOES'] >= 7).sum(),
        '4, 5 ou 6 reprovações': g['TOTAL_REPROVACOES'].between(4, 6).sum(),
        '3 ou menos reprovações': (g['TOTAL_REPROVACOES'] <= 3).sum()
    }))
    .reset_index()
)

# %%
resultado_por_serie
# Out:
#       SÉRIE  Total em distorção idade-série  7 ou mais reprovações  \
# 0  1ª SÉRIE                            7123                   2963
# 1  2ª SÉRIE                            4448                   1080
# 2  3ª SÉRIE                            3272                    522
# 3    6º ANO                            1765                    432
# 4    7º ANO                            1767                    334
# 5    8º ANO                            1344                    154
# 6    9º ANO                            1030                    117
#
#    4, 5 ou 6 reprovações  3 ou menos reprovações
# 0                   1889                    2271
# 1                   1127                    2241
# 2                    771                    1979
# 3                    667                     666
# 4                    675                     758
# 5                    481                     709
# 6                    334                     579
