# %%
# Bibliotecas

import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Carregar a planilha e depois selecionar as colunas de interesse
df = pd.read_excel(r"C:\Users\hugob\Downloads\20251010_Relatório Geral de Estudantes - Matrículas.xlsx")

# %%
df
# Out:
#        Relatório Geral de Estudantes - Matrículas Unnamed: 1    Unnamed: 2  \
# 0                      Gerado em 10/10/2025 16:43        NaN           NaN
# 1                                             ANO    PERÍODO     MATRÍCULA
# 2                                            2025          1  202130232924
# 3                                            2025          1  202230683131
# 4                                            2025          1  201930003743
# ...                                           ...        ...           ...
# 235546                                       2025          1  202530498839
# 235547                                       2025          1  202330283867
# 235548                                       2025          1  202530498848
# 235549                                       2025          2  202330365864
# 235550                                       2025          1  202530498857
#
#                              Unnamed: 3                        Unnamed: 4  \
# 0                                   NaN                               NaN
# 1       DATA DE EFETIVAÇÃO DA MATRÍCULA                              NOME
# 2                            13/11/2024      JOAO GABRIEL DA SILVA ARAUJO
# 3                            13/11/2024              BRUNO CORTES SANTANA
# 4                            13/11/2024        ALISSON DE FARIAS COUTINHO
# ...                                 ...                               ...
# 235546                       10/10/2025    VITORIA RAFAELLY DE LIMA SILVA
# 235547                       10/10/2025         HUGO SAMUEL LIMA DA SILVA
# 235548                       10/10/2025    MARIA CECILIA BATISTA DA SILVA
# 235549                       10/10/2025  VANESSA EMILY PEREIRA DE MENEZES
# 235550                       10/10/2025        JOAO BATISTA SOUZA DE LIMA
#
#          Unnamed: 5 Unnamed: 6 Unnamed: 7                      Unnamed: 8  \
# 0               NaN        NaN        NaN                             NaN
# 1       NOME SOCIAL  ID_PESSOA       SEXO              NOME DA FILIAÇÃO 1
# 2                 -    1236483          M           MARIA RENATA DA SILVA
# 3                 -    1382152          M    LUCIANA COSTA CORTES SANTANA
# 4                 -    1055307          M          JOSEFA MARIA DE FARIAS
# ...             ...        ...        ...                             ...
# 235546            -    1583599          M     RAFAELA SUANE DE LIMA SILVA
# 235547            -    1413979          M           JESSICA LIMA DA SILVA
# 235548            -    1583600          F  CICERA DEUZALETE MOTA DA SILVA
# 235549            -    1422224          F              CRISTIANNY PEREIRA
# 235550            -    1583601          M   CASSIA TUANE REBOUCAS DE LIMA
#
#                            Unnamed: 9  ...       Unnamed: 33  \
# 0                                 NaN  ...               NaN
# 1                  NOME DA FILIAÇÃO 2  ...  DATA DA OPERAÇÃO
# 2             GILMARQUES ARAUJO SILVA  ...        2024-12-30
# 3                                 NaN  ...        2025-03-10
# 4       JOSE AELSON COUTINHO DA COSTA  ...        2025-02-12
# ...                               ...  ...               ...
# 235546    JOAO BATISTA GOMES DA SILVA  ...        2025-10-10
# 235547         RAFAEL DANTAS CORDEIRO  ...        2025-10-10
# 235548     ADEMIR BATISTA DA TRINDADE  ...        2025-10-10
# 235549          JOAO MARIA DE MENEZES  ...        2025-10-10
# 235550                            NaN  ...        2025-10-10
#
#                            Unnamed: 34         Unnamed: 35   Unnamed: 36  \
# 0                                  NaN                 NaN           NaN
# 1                          RESPÓNSÁVEL  MATRICULA SERVIDOR         LOGIN
# 2                                    -                   -  202130232924
# 3                                    -                   -             -
# 4       JOSENILZA LUCIA DOS REIS ALVES             1255185             -
# ...                                ...                 ...           ...
# 235546                               -                   -             -
# 235547                               -                   -             -
# 235548                               -                   -             -
# 235549                               -                   -             -
# 235550                               -                   -             -
#
#        Unnamed: 37           Unnamed: 38 Unnamed: 39  \
# 0              NaN                   NaN         NaN
# 1       ID_USUÁRIO  PARTICIPA PÉ DE MEIA  RAÇA / COR
# 2         61976060                   Não       Parda
# 3                -                   Não       Parda
# 4                -                   Não       Parda
# ...            ...                   ...         ...
# 235546           -                   Não       Parda
# 235547           -                   Não       Preta
# 235548           -                   Não       Parda
# 235549           -                   Sim       Parda
# 235550           -                   Não       Parda
#
#                        Unnamed: 40                 Unnamed: 41 Unnamed: 42
# 0                              NaN                         NaN         NaN
# 1       UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR        TIPO
# 2                              Sim                      Ônibus    ESTADUAL
# 3                              Não                           -           -
# 4                              Não                           -           -
# ...                            ...                         ...         ...
# 235546                         Sim                      Ônibus    ESTADUAL
# 235547                         Não                           -           -
# 235548                         Sim                Micro-ônibus    ESTADUAL
# 235549                         Sim                      Ônibus   MUNICIPAL
# 235550                         Não                           -           -
#
# [235551 rows x 43 columns]

# %%
df = df.drop(index=0)

# %%
df.columns = df.iloc[0]

# %%
df
# Out:
# 1        ANO  PERÍODO     MATRÍCULA  DATA DE EFETIVAÇÃO DA MATRÍCULA  \
# 1        ANO  PERÍODO     MATRÍCULA  DATA DE EFETIVAÇÃO DA MATRÍCULA
# 2       2025        1  202130232924                       13/11/2024
# 3       2025        1  202230683131                       13/11/2024
# 4       2025        1  201930003743                       13/11/2024
# 5       2025        1  202430157363                       13/11/2024
# ...      ...      ...           ...                              ...
# 235546  2025        1  202530498839                       10/10/2025
# 235547  2025        1  202330283867                       10/10/2025
# 235548  2025        1  202530498848                       10/10/2025
# 235549  2025        2  202330365864                       10/10/2025
# 235550  2025        1  202530498857                       10/10/2025
#
# 1                                    NOME  NOME SOCIAL  ID_PESSOA  SEXO  \
# 1                                    NOME  NOME SOCIAL  ID_PESSOA  SEXO
# 2            JOAO GABRIEL DA SILVA ARAUJO            -    1236483     M
# 3                    BRUNO CORTES SANTANA            -    1382152     M
# 4              ALISSON DE FARIAS COUTINHO            -    1055307     M
# 5       JALLYSON MIGUEL SILVA DE OLIVEIRA            -    1478210     M
# ...                                   ...          ...        ...   ...
# 235546     VITORIA RAFAELLY DE LIMA SILVA            -    1583599     M
# 235547          HUGO SAMUEL LIMA DA SILVA            -    1413979     M
# 235548     MARIA CECILIA BATISTA DA SILVA            -    1583600     F
# 235549   VANESSA EMILY PEREIRA DE MENEZES            -    1422224     F
# 235550         JOAO BATISTA SOUZA DE LIMA            -    1583601     M
#
# 1                   NOME DA FILIAÇÃO 1             NOME DA FILIAÇÃO 2  ...  \
# 1                   NOME DA FILIAÇÃO 1             NOME DA FILIAÇÃO 2  ...
# 2                MARIA RENATA DA SILVA        GILMARQUES ARAUJO SILVA  ...
# 3         LUCIANA COSTA CORTES SANTANA                            NaN  ...
# 4               JOSEFA MARIA DE FARIAS  JOSE AELSON COUTINHO DA COSTA  ...
# 5                 MARIANA SILVA FARIAS    JANAILSON LOPES DE OLIVEIRA  ...
# ...                                ...                            ...  ...
# 235546     RAFAELA SUANE DE LIMA SILVA    JOAO BATISTA GOMES DA SILVA  ...
# 235547           JESSICA LIMA DA SILVA         RAFAEL DANTAS CORDEIRO  ...
# 235548  CICERA DEUZALETE MOTA DA SILVA     ADEMIR BATISTA DA TRINDADE  ...
# 235549              CRISTIANNY PEREIRA          JOAO MARIA DE MENEZES  ...
# 235550   CASSIA TUANE REBOUCAS DE LIMA                            NaN  ...
#
# 1       DATA DA OPERAÇÃO                     RESPÓNSÁVEL  MATRICULA SERVIDOR  \
# 1       DATA DA OPERAÇÃO                     RESPÓNSÁVEL  MATRICULA SERVIDOR
# 2             2024-12-30                               -                   -
# 3             2025-03-10                               -                   -
# 4             2025-02-12  JOSENILZA LUCIA DOS REIS ALVES             1255185
# 5             2025-03-10                               -                   -
# ...                  ...                             ...                 ...
# 235546        2025-10-10                               -                   -
# 235547        2025-10-10                               -                   -
# 235548        2025-10-10                               -                   -
# 235549        2025-10-10                               -                   -
# 235550        2025-10-10                               -                   -
#
# 1              LOGIN  ID_USUÁRIO  PARTICIPA PÉ DE MEIA  RAÇA / COR  \
# 1              LOGIN  ID_USUÁRIO  PARTICIPA PÉ DE MEIA  RAÇA / COR
# 2       202130232924    61976060                   Não       Parda
# 3                  -           -                   Não       Parda
# 4                  -           -                   Não       Parda
# 5                  -           -                   Não       Parda
# ...              ...         ...                   ...         ...
# 235546             -           -                   Não       Parda
# 235547             -           -                   Não       Preta
# 235548             -           -                   Não       Parda
# 235549             -           -                   Sim       Parda
# 235550             -           -                   Não       Parda
#
# 1       UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR       TIPO
# 1       UTILIZA TRANSPORTE ESCOLAR  TIPO DE TRANSPORTE ESCOLAR       TIPO
# 2                              Sim                      Ônibus   ESTADUAL
# 3                              Não                           -          -
# 4                              Não                           -          -
# 5                              Sim                Micro-ônibus   ESTADUAL
# ...                            ...                         ...        ...
# 235546                         Sim                      Ônibus   ESTADUAL
# 235547                         Não                           -          -
# 235548                         Sim                Micro-ônibus   ESTADUAL
# 235549                         Sim                      Ônibus  MUNICIPAL
# 235550                         Não                           -          -
#
# [235550 rows x 43 columns]

# %%
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 1        ANO PERÍODO     MATRÍCULA DATA DE EFETIVAÇÃO DA MATRÍCULA  \
# 0       2025       1  202130232924                      13/11/2024
# 1       2025       1  202230683131                      13/11/2024
# 2       2025       1  201930003743                      13/11/2024
# 3       2025       1  202430157363                      13/11/2024
# 4       2025       1  202430266223                      14/11/2024
# ...      ...     ...           ...                             ...
# 235544  2025       1  202530498839                      10/10/2025
# 235545  2025       1  202330283867                      10/10/2025
# 235546  2025       1  202530498848                      10/10/2025
# 235547  2025       2  202330365864                      10/10/2025
# 235548  2025       1  202530498857                      10/10/2025
#
# 1                                    NOME NOME SOCIAL ID_PESSOA SEXO  \
# 0            JOAO GABRIEL DA SILVA ARAUJO           -   1236483    M
# 1                    BRUNO CORTES SANTANA           -   1382152    M
# 2              ALISSON DE FARIAS COUTINHO           -   1055307    M
# 3       JALLYSON MIGUEL SILVA DE OLIVEIRA           -   1478210    M
# 4               ANA SOPHIA ABREU DA SILVA           -   1489101    F
# ...                                   ...         ...       ...  ...
# 235544     VITORIA RAFAELLY DE LIMA SILVA           -   1583599    M
# 235545          HUGO SAMUEL LIMA DA SILVA           -   1413979    M
# 235546     MARIA CECILIA BATISTA DA SILVA           -   1583600    F
# 235547   VANESSA EMILY PEREIRA DE MENEZES           -   1422224    F
# 235548         JOAO BATISTA SOUZA DE LIMA           -   1583601    M
#
# 1                    NOME DA FILIAÇÃO 1             NOME DA FILIAÇÃO 2  ...  \
# 0                 MARIA RENATA DA SILVA        GILMARQUES ARAUJO SILVA  ...
# 1          LUCIANA COSTA CORTES SANTANA                            NaN  ...
# 2                JOSEFA MARIA DE FARIAS  JOSE AELSON COUTINHO DA COSTA  ...
# 3                  MARIANA SILVA FARIAS    JANAILSON LOPES DE OLIVEIRA  ...
# 4       SUELEN CRISTINA DE ABREU LORENA     JOSE PAULO DA SILVA JUNIOR  ...
# ...                                 ...                            ...  ...
# 235544      RAFAELA SUANE DE LIMA SILVA    JOAO BATISTA GOMES DA SILVA  ...
# 235545            JESSICA LIMA DA SILVA         RAFAEL DANTAS CORDEIRO  ...
# 235546   CICERA DEUZALETE MOTA DA SILVA     ADEMIR BATISTA DA TRINDADE  ...
# 235547               CRISTIANNY PEREIRA          JOAO MARIA DE MENEZES  ...
# 235548    CASSIA TUANE REBOUCAS DE LIMA                            NaN  ...
#
# 1      DATA DA OPERAÇÃO                     RESPÓNSÁVEL MATRICULA SERVIDOR  \
# 0            2024-12-30                               -                  -
# 1            2025-03-10                               -                  -
# 2            2025-02-12  JOSENILZA LUCIA DOS REIS ALVES            1255185
# 3            2025-03-10                               -                  -
# 4            2025-03-10                               -                  -
# ...                 ...                             ...                ...
# 235544       2025-10-10                               -                  -
# 235545       2025-10-10                               -                  -
# 235546       2025-10-10                               -                  -
# 235547       2025-10-10                               -                  -
# 235548       2025-10-10                               -                  -
#
# 1              LOGIN ID_USUÁRIO PARTICIPA PÉ DE MEIA RAÇA / COR  \
# 0       202130232924   61976060                  Não      Parda
# 1                  -          -                  Não      Parda
# 2                  -          -                  Não      Parda
# 3                  -          -                  Não      Parda
# 4                  -          -                  Não      Parda
# ...              ...        ...                  ...        ...
# 235544             -          -                  Não      Parda
# 235545             -          -                  Não      Preta
# 235546             -          -                  Não      Parda
# 235547             -          -                  Sim      Parda
# 235548             -          -                  Não      Parda
#
# 1      UTILIZA TRANSPORTE ESCOLAR TIPO DE TRANSPORTE ESCOLAR       TIPO
# 0                             Sim                     Ônibus   ESTADUAL
# 1                             Não                          -          -
# 2                             Não                          -          -
# 3                             Sim               Micro-ônibus   ESTADUAL
# 4                             Não                          -          -
# ...                           ...                        ...        ...
# 235544                        Sim                     Ônibus   ESTADUAL
# 235545                        Não                          -          -
# 235546                        Sim               Micro-ônibus   ESTADUAL
# 235547                        Sim                     Ônibus  MUNICIPAL
# 235548                        Não                          -          -
#
# [235549 rows x 43 columns]

# %%
# Deixar somente as 2 colunas de interesse (CPF e DATA DE NASCIMENTO)
df = df[['CPF', 'DATA DE NASCIMENTO']]

# %%
df
# Out:
# 1                  CPF   DATA DE NASCIMENTO
# 0       708.241.414-58  2014-02-27 00:00:00
# 1       073.022.765-01  2012-10-31 00:00:00
# 2       708.610.634-81  2012-11-01 00:00:00
# 3       141.327.644-00  2016-03-02 00:00:00
# 4       147.265.004-22  2017-08-17 00:00:00
# ...                ...                  ...
# 235544  132.482.834-08  2012-12-11 00:00:00
# 235545  145.382.934-23  2011-05-25 00:00:00
# 235546  717.790.464-64  2010-11-04 00:00:00
# 235547  707.242.084-37  2006-08-12 00:00:00
# 235548  163.826.264-06  2019-03-17 00:00:00
#
# [235549 rows x 2 columns]

# %%
# Definir a data de referência (10 de outubro de 2025)
data_referencia = datetime(2025, 10, 10)

# %%
# Converter a coluna de data para formato datetime
df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%d/%m/%Y %H:%M')
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_3804\199283761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%d/%m/%Y %H:%M')

# %%
# Calcular as idades usando a data de referência
df['IDADE'] = (data_referencia - df['DATA DE NASCIMENTO']).dt.days // 365
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_3804\1383963767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IDADE'] = (data_referencia - df['DATA DE NASCIMENTO']).dt.days // 365

# %%
df
# Out:
# 1                  CPF DATA DE NASCIMENTO  IDADE
# 0       708.241.414-58         2014-02-27     11
# 1       073.022.765-01         2012-10-31     12
# 2       708.610.634-81         2012-11-01     12
# 3       141.327.644-00         2016-03-02      9
# 4       147.265.004-22         2017-08-17      8
# ...                ...                ...    ...
# 235544  132.482.834-08         2012-12-11     12
# 235545  145.382.934-23         2011-05-25     14
# 235546  717.790.464-64         2010-11-04     14
# 235547  707.242.084-37         2006-08-12     19
# 235548  163.826.264-06         2019-03-17      6
#
# [235549 rows x 3 columns]

# %%
# Carregar a planilha e depois selecionar as colunas de interesse
df_notas = pd.read_parquet(r"C:\Users\hugob\Downloads\df_EF_EM_bncc.parquet")

# %%
df_notas
# Out:
#                              DIREC                MUNICÍPIO  \
# 2000             10ª DIREC - CAICÓ                    CAICO
# 2001             10ª DIREC - CAICÓ                    CAICO
# 2002             10ª DIREC - CAICÓ                    CAICO
# 2003             10ª DIREC - CAICÓ                    CAICO
# 2004             10ª DIREC - CAICÓ                    CAICO
# ...                            ...                      ...
# 2960921  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2960922  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2960923  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2960928  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 2960934  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
#
#                                                     ESCOLA  INEP ESCOLA  \
# 2000                                       CE JOSE AUGUSTO     24031348
# 2001                                       CE JOSE AUGUSTO     24031348
# 2002                                       CE JOSE AUGUSTO     24031348
# 2003                                       CE JOSE AUGUSTO     24031348
# 2004                                       CE JOSE AUGUSTO     24031348
# ...                                                    ...          ...
# 2960921  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2960922  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2960923  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2960928  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 2960934  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
#
#                                               ETAPA ENSINO     SÉRIE  \
# 2000     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2001     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2002     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2003     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2004     CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# ...                                                    ...       ...
# 2960921            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2960922            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2960923            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2960928            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 2960934            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
#
#         COMPONENTE CURRICULAR   CPF PESSOA                      NOME PESSOA  \
# 2000                     Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2001                     Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2002                 Biologia  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2003          Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2004          Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# ...                       ...          ...                              ...
# 2960921     Língua Portuguesa  13717816489          WELLINGTON ARAUJO FELIX
# 2960922            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 2960923            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 2960928               Química  13717816489          WELLINGTON ARAUJO FELIX
# 2960934            Sociologia  13717816489          WELLINGTON ARAUJO FELIX
#
#          NOTA 1º BIMESTRE  NOTA 2º BIMESTRE  NOTA 3º BIMESTRE  \
# 2000                  8.6               9.0               NaN
# 2001                  8.6               9.0               NaN
# 2002                  6.8               7.1               NaN
# 2003                  8.3               9.0               NaN
# 2004                  8.3               9.0               NaN
# ...                   ...               ...               ...
# 2960921               4.6               4.2               NaN
# 2960922               6.1               3.3               NaN
# 2960923               6.1               3.3               NaN
# 2960928               6.0               6.0               6.0
# 2960934               8.0               8.0               8.5
#
#          NOTA 4º BIMESTRE  MÉDIA ANUAL  EXAME FINAL  AVALIAÇÃO ESPECIAL  \
# 2000                  NaN          NaN          NaN                 NaN
# 2001                  NaN          NaN          NaN                 NaN
# 2002                  NaN          NaN          NaN                 NaN
# 2003                  NaN          NaN          NaN                 NaN
# 2004                  NaN          NaN          NaN                 NaN
# ...                   ...          ...          ...                 ...
# 2960921               NaN          NaN          NaN                 NaN
# 2960922               NaN          NaN          NaN                 NaN
# 2960923               NaN          NaN          NaN                 NaN
# 2960928               NaN          NaN          NaN                 NaN
# 2960934               NaN          NaN          NaN                 NaN
#
#          MÉDIA FINAL ETAPA_RESUMIDA  MEDIA_1_2_BIM     STATUS
# 2000             NaN   Ensino Médio           8.80   Aprovado
# 2001             NaN   Ensino Médio           8.80   Aprovado
# 2002             NaN   Ensino Médio           6.95   Aprovado
# 2003             NaN   Ensino Médio           8.65   Aprovado
# 2004             NaN   Ensino Médio           8.65   Aprovado
# ...              ...            ...            ...        ...
# 2960921          NaN   Ensino Médio           4.40  Reprovado
# 2960922          NaN   Ensino Médio           4.70  Reprovado
# 2960923          NaN   Ensino Médio           4.70  Reprovado
# 2960928          NaN   Ensino Médio           6.00   Aprovado
# 2960934          NaN   Ensino Médio           8.00   Aprovado
#
# [1579661 rows x 20 columns]

# %%
df['CPF'] = df['CPF'].astype(str).str.replace('.', '', regex=False).str.replace('-', '', regex=False)
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_3804\1005790323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CPF'] = df['CPF'].astype(str).str.replace('.', '', regex=False).str.replace('-', '', regex=False)

# %%
# Out:
# 1               CPF DATA DE NASCIMENTO  IDADE
# 0       70824141458         2014-02-27     11
# 1       07302276501         2012-10-31     12
# 2       70861063481         2012-11-01     12
# 3       14132764400         2016-03-02      9
# 4       14726500422         2017-08-17      8
# ...             ...                ...    ...
# 235544  13248283408         2012-12-11     12
# 235545  14538293423         2011-05-25     14
# 235546  71779046464         2010-11-04     14
# 235547  70724208437         2006-08-12     19
# 235548  16382626406         2019-03-17      6
#
# [235549 rows x 3 columns]

# %%
# MErge para adicionar idade no dataframe df_notas

df_notas = df_notas.merge(
    df[['CPF', 'IDADE']],      # DataFrame com as colunas que você quer trazer
    how='left',                # mantém todas as linhas do df_notas
    left_on='CPF PESSOA',      # coluna de df_notas usada para combinar
    right_on='CPF'             # coluna de df usada para combinar
)

# %%
df_notas
# Out:
#                              DIREC                MUNICÍPIO  \
# 0                10ª DIREC - CAICÓ                    CAICO
# 1                10ª DIREC - CAICÓ                    CAICO
# 2                10ª DIREC - CAICÓ                    CAICO
# 3                10ª DIREC - CAICÓ                    CAICO
# 4                10ª DIREC - CAICÓ                    CAICO
# ...                            ...                      ...
# 1731178  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1731179  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1731180  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1731181  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
# 1731182  09ª DIREC - CURRAIS NOVOS  TENENTE LAURENTINO CRUZ
#
#                                                     ESCOLA  INEP ESCOLA  \
# 0                                          CE JOSE AUGUSTO     24031348
# 1                                          CE JOSE AUGUSTO     24031348
# 2                                          CE JOSE AUGUSTO     24031348
# 3                                          CE JOSE AUGUSTO     24031348
# 4                                          CE JOSE AUGUSTO     24031348
# ...                                                    ...          ...
# 1731178  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1731179  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1731180  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1731181  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
# 1731182  ESCOLA ESTADUAL PADRE SINVAL LAURENTINO DE MED...     24066168
#
#                                               ETAPA ENSINO     SÉRIE  \
# 0        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 1        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 2        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 3        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# 4        CURSO TÉCNICO DE NÍVEL MÉDIO EM MANUTENÇÃO E S...  1ª SÉRIE
# ...                                                    ...       ...
# 1731178            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1731179            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1731180            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1731181            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
# 1731182            ENSINO MÉDIO POTIGUAR EM TEMPO INTEGRAL  2ª SÉRIE
#
#         COMPONENTE CURRICULAR   CPF PESSOA                      NOME PESSOA  \
# 0                        Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 1                        Arte  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 2                    Biologia  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 3             Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# 4             Educação Física  70602180414  DAVYSON EMANOEL DA SILVA SANTOS
# ...                       ...          ...                              ...
# 1731178     Língua Portuguesa  13717816489          WELLINGTON ARAUJO FELIX
# 1731179            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 1731180            Matemática  13717816489          WELLINGTON ARAUJO FELIX
# 1731181               Química  13717816489          WELLINGTON ARAUJO FELIX
# 1731182            Sociologia  13717816489          WELLINGTON ARAUJO FELIX
#
#          NOTA 1º BIMESTRE  ...  NOTA 4º BIMESTRE  MÉDIA ANUAL  EXAME FINAL  \
# 0                     8.6  ...               NaN          NaN          NaN
# 1                     8.6  ...               NaN          NaN          NaN
# 2                     6.8  ...               NaN          NaN          NaN
# 3                     8.3  ...               NaN          NaN          NaN
# 4                     8.3  ...               NaN          NaN          NaN
# ...                   ...  ...               ...          ...          ...
# 1731178               4.6  ...               NaN          NaN          NaN
# 1731179               6.1  ...               NaN          NaN          NaN
# 1731180               6.1  ...               NaN          NaN          NaN
# 1731181               6.0  ...               NaN          NaN          NaN
# 1731182               8.0  ...               NaN          NaN          NaN
#
#          AVALIAÇÃO ESPECIAL  MÉDIA FINAL  ETAPA_RESUMIDA  MEDIA_1_2_BIM  \
# 0                       NaN          NaN    Ensino Médio           8.80
# 1                       NaN          NaN    Ensino Médio           8.80
# 2                       NaN          NaN    Ensino Médio           6.95
# 3                       NaN          NaN    Ensino Médio           8.65
# 4                       NaN          NaN    Ensino Médio           8.65
# ...                     ...          ...             ...            ...
# 1731178                 NaN          NaN    Ensino Médio           4.40
# 1731179                 NaN          NaN    Ensino Médio           4.70
# 1731180                 NaN          NaN    Ensino Médio           4.70
# 1731181                 NaN          NaN    Ensino Médio           6.00
# 1731182                 NaN          NaN    Ensino Médio           8.00
#
#             STATUS          CPF IDADE
# 0         Aprovado  70602180414  16.0
# 1         Aprovado  70602180414  16.0
# 2         Aprovado  70602180414  16.0
# 3         Aprovado  70602180414  16.0
# 4         Aprovado  70602180414  16.0
# ...            ...          ...   ...
# 1731178  Reprovado  13717816489  19.0
# 1731179  Reprovado  13717816489  19.0
# 1731180  Reprovado  13717816489  19.0
# 1731181   Aprovado  13717816489  19.0
# 1731182   Aprovado  13717816489  19.0
#
# [1731183 rows x 22 columns]

# %%
# Função auxiliar para pegar o valor mais frequente (modo)
def modo(serie):
    return serie.mode()[0] if not serie.mode().empty else None

# Agrupar e calcular
df_reprovacoes = (
    df_notas.groupby('CPF PESSOA', as_index=False)
    .agg({
        'STATUS': lambda x: (x == 'Reprovado').sum(),  # Conta quantos "Reprovado"
        'IDADE': modo,                                # Valor mais frequente da idade
        'SÉRIE': modo                                 # Valor mais frequente da série
    })
)

# Renomear a coluna resultante
df_reprovacoes.rename(columns={'STATUS': 'TOTAL_REPROVACOES'}, inplace=True)

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE
# 0                 -                 33    NaN    9º ANO
# 1       10000150410                 12   18.0  3ª SÉRIE
# 2       10000254460                  0   17.0  1ª SÉRIE
# 3       10000823422                  0   18.0  3ª SÉRIE
# 4       10000982490                  1   17.0  2ª SÉRIE
# ...             ...                ...    ...       ...
# 137169   9997488407                  1    NaN  2ª SÉRIE
# 137170   9998899400                  0    NaN  2ª SÉRIE
# 137171   9999048412                  0    NaN  3ª SÉRIE
# 137172    999906445                  0    NaN  3ª SÉRIE
# 137173   9999339492                  0    NaN  2ª SÉRIE
#
# [137174 rows x 4 columns]

# %%
df_reprovacoes['SÉRIE'].unique()
# Out:
# array(['9º ANO', '3ª SÉRIE', '1ª SÉRIE', '2ª SÉRIE', '6º ANO', '8º ANO',
#        '7º ANO'], dtype=object)

# %%
# Dicionário de mapeamento entre série e idade esperada
mapa_idade_esperada = {
    '6º ANO': 11,
    '7º ANO': 12,
    '8º ANO': 13,
    '9º ANO': 14,
    '1ª SÉRIE': 15,
    '2ª SÉRIE': 16,
    '3ª SÉRIE': 17
}

# Criar nova coluna com base na série
df_reprovacoes['IDADE_ESPERADA'] = df_reprovacoes['SÉRIE'].map(mapa_idade_esperada)

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA
# 0                 -                 33    NaN    9º ANO              14
# 1       10000150410                 12   18.0  3ª SÉRIE              17
# 2       10000254460                  0   17.0  1ª SÉRIE              15
# 3       10000823422                  0   18.0  3ª SÉRIE              17
# 4       10000982490                  1   17.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 137169   9997488407                  1    NaN  2ª SÉRIE              16
# 137170   9998899400                  0    NaN  2ª SÉRIE              16
# 137171   9999048412                  0    NaN  3ª SÉRIE              17
# 137172    999906445                  0    NaN  3ª SÉRIE              17
# 137173   9999339492                  0    NaN  2ª SÉRIE              16
#
# [137174 rows x 5 columns]

# %%
# Diferença entre Idade e Idade Esperada
df_reprovacoes['DIFERENCA'] = df_reprovacoes['IDADE'] - df_reprovacoes['IDADE_ESPERADA']

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 0                 -                 33    NaN    9º ANO              14
# 1       10000150410                 12   18.0  3ª SÉRIE              17
# 2       10000254460                  0   17.0  1ª SÉRIE              15
# 3       10000823422                  0   18.0  3ª SÉRIE              17
# 4       10000982490                  1   17.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 137169   9997488407                  1    NaN  2ª SÉRIE              16
# 137170   9998899400                  0    NaN  2ª SÉRIE              16
# 137171   9999048412                  0    NaN  3ª SÉRIE              17
# 137172    999906445                  0    NaN  3ª SÉRIE              17
# 137173   9999339492                  0    NaN  2ª SÉRIE              16
#
#         DIFERENCA
# 0             NaN
# 1             1.0
# 2             2.0
# 3             1.0
# 4             1.0
# ...           ...
# 137169        NaN
# 137170        NaN
# 137171        NaN
# 137172        NaN
# 137173        NaN
#
# [137174 rows x 6 columns]

# %%
# Coluna de identificação dos estudantes em distorção idade-série (2 ou mais anos de diferença entre idade atual e idade esperada para a série)
df_reprovacoes['DISTORCAO'] = np.where(df_reprovacoes['DIFERENCA'] >= 2, 'Sim', 'Não')

# %%
df_reprovacoes
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 0                 -                 33    NaN    9º ANO              14
# 1       10000150410                 12   18.0  3ª SÉRIE              17
# 2       10000254460                  0   17.0  1ª SÉRIE              15
# 3       10000823422                  0   18.0  3ª SÉRIE              17
# 4       10000982490                  1   17.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 137169   9997488407                  1    NaN  2ª SÉRIE              16
# 137170   9998899400                  0    NaN  2ª SÉRIE              16
# 137171   9999048412                  0    NaN  3ª SÉRIE              17
# 137172    999906445                  0    NaN  3ª SÉRIE              17
# 137173   9999339492                  0    NaN  2ª SÉRIE              16
#
#         DIFERENCA DISTORCAO
# 0             NaN       Não
# 1             1.0       Não
# 2             2.0       Sim
# 3             1.0       Não
# 4             1.0       Não
# ...           ...       ...
# 137169        NaN       Não
# 137170        NaN       Não
# 137171        NaN       Não
# 137172        NaN       Não
# 137173        NaN       Não
#
# [137174 rows x 7 columns]

# %%
df_distorcao = df_reprovacoes[df_reprovacoes['DISTORCAO'] == 'Sim'].copy()

# %%
df_distorcao
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 2       10000254460                  0   17.0  1ª SÉRIE              15
# 6       10001342452                  0   16.0    9º ANO              14
# 12      10005741483                  2   20.0  2ª SÉRIE              16
# 14      10005942462                  0   16.0    9º ANO              14
# 19      10007642490                  3   18.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 136171  94311943253                  0   21.0  1ª SÉRIE              15
# 136173  94336830487                  1   47.0  1ª SÉRIE              15
# 136516  96612770449                  0   57.0  3ª SÉRIE              17
# 136580  97025640425                  2   50.0  1ª SÉRIE              15
# 136597  97131857491                  8   52.0  3ª SÉRIE              17
#
#         DIFERENCA DISTORCAO
# 2             2.0       Sim
# 6             2.0       Sim
# 12            4.0       Sim
# 14            2.0       Sim
# 19            2.0       Sim
# ...           ...       ...
# 136171        6.0       Sim
# 136173       32.0       Sim
# 136516       40.0       Sim
# 136580       35.0       Sim
# 136597       35.0       Sim
#
# [37766 rows x 7 columns]

# %%
# COluna de Etapa
# Definir as condições
condicoes = [
    df_distorcao['SÉRIE'].isin(['6º ANO', '7º ANO', '8º ANO', '9º ANO']),
    df_distorcao['SÉRIE'].isin(['1ª SÉRIE', '2ª SÉRIE', '3ª SÉRIE'])
]

# Definir os valores correspondentes
valores = [
    'Ensino Fundamental - Anos Finais',
    'Ensino Médio'
]

# Criar a nova coluna 'ETAPA'
df_distorcao['ETAPA'] = np.select(condicoes, valores, default='Outro')

# %%
df_distorcao
# Out:
#          CPF PESSOA  TOTAL_REPROVACOES  IDADE     SÉRIE  IDADE_ESPERADA  \
# 2       10000254460                  0   17.0  1ª SÉRIE              15
# 6       10001342452                  0   16.0    9º ANO              14
# 12      10005741483                  2   20.0  2ª SÉRIE              16
# 14      10005942462                  0   16.0    9º ANO              14
# 19      10007642490                  3   18.0  2ª SÉRIE              16
# ...             ...                ...    ...       ...             ...
# 136171  94311943253                  0   21.0  1ª SÉRIE              15
# 136173  94336830487                  1   47.0  1ª SÉRIE              15
# 136516  96612770449                  0   57.0  3ª SÉRIE              17
# 136580  97025640425                  2   50.0  1ª SÉRIE              15
# 136597  97131857491                  8   52.0  3ª SÉRIE              17
#
#         DIFERENCA DISTORCAO                             ETAPA
# 2             2.0       Sim                      Ensino Médio
# 6             2.0       Sim  Ensino Fundamental - Anos Finais
# 12            4.0       Sim                      Ensino Médio
# 14            2.0       Sim  Ensino Fundamental - Anos Finais
# 19            2.0       Sim                      Ensino Médio
# ...           ...       ...                               ...
# 136171        6.0       Sim                      Ensino Médio
# 136173       32.0       Sim                      Ensino Médio
# 136516       40.0       Sim                      Ensino Médio
# 136580       35.0       Sim                      Ensino Médio
# 136597       35.0       Sim                      Ensino Médio
#
# [37766 rows x 8 columns]

# %%
# Garantir que TOTAL_REPROVACOES é numérico
df_distorcao['TOTAL_REPROVACOES'] = pd.to_numeric(df_distorcao['TOTAL_REPROVACOES'], errors='coerce')

# Calcular as quantidades em cada faixa
qtd_7_ou_mais = (df_distorcao['TOTAL_REPROVACOES'] >= 7).sum()
qtd_4_a_6 = df_distorcao['TOTAL_REPROVACOES'].between(4, 6).sum()
qtd_3_ou_menos = (df_distorcao['TOTAL_REPROVACOES'] <= 3).sum()

# Mostrar o resultado
print("Total em distorção idade-série:", len(df_distorcao))
print("7 ou mais reprovações:", qtd_7_ou_mais)
print("4, 5 ou 6 reprovações:", qtd_4_a_6)
print("3 ou menos reprovações:", qtd_3_ou_menos)
# Out:
# Total em distorção idade-série: 37766
# 7 ou mais reprovações: 10328
# 4, 5 ou 6 reprovações: 10042
# 3 ou menos reprovações: 17396

# %%
# Cálculo por etapa:
# Agrupar por ETAPA e calcular as quantidades em cada faixa
resultado_por_etapa = (
    df_distorcao
    .groupby('ETAPA')
    .apply(lambda g: pd.Series({
        'Total em distorção idade-série': len(g),
        '7 ou mais reprovações': (g['TOTAL_REPROVACOES'] >= 7).sum(),
        '4, 5 ou 6 reprovações': g['TOTAL_REPROVACOES'].between(4, 6).sum(),
        '3 ou menos reprovações': (g['TOTAL_REPROVACOES'] <= 3).sum()
    }))
    .reset_index()
)

# %%
resultado_por_etapa
# Out:
#                               ETAPA  Total em distorção idade-série  \
# 0  Ensino Fundamental - Anos Finais                           11539
# 1                      Ensino Médio                           26227
#
#    7 ou mais reprovações  4, 5 ou 6 reprovações  3 ou menos reprovações
# 0                   2081                   3693                    5765
# 1                   8247                   6349                   11631
